# %% [markdown]
# # 02 - Anatomy
#
# **Before you start:**
#
# - Give each concrete step in the process its own cell. If you can't describe what a cell does in a short phrase ("load the text file," "strip punctuation," "count word frequency"), it's probably two steps — split it into two cells.
# - Add a Markdown cell above each code cell explaining what you're about to do and *why* — write the explanation **before** you write the code. This forces you to say what you expect to happen before you find out what actually happens.
# - Use `#` comments inside code cells for line-level notes (why a line is written a certain way, what a tricky argument does, reminders to yourself).
# - Log anything that breaks in the **Failure Log** at the bottom of this notebook — even if you never fixed it. Note the error message and what you tried.
#
# Rename this file using the format `LastName-##-UnitTopic-Notebook.ipynb` before you begin (e.g. `Proctor-02-Python-Basics-Notebook.ipynb`).

# %% [markdown]
# ## Imports
#
# Run this cell once, at the start of your session. Add every `import` statement for this notebook here — you shouldn't need to re-run this as you work through the rest of the notebook.

# %% [markdown]
# *I am going to import a couple of libraries to allow me to analyze some text*

# %%
import re
from collections import Counter

# %% [markdown]
# ---
#
# ## Your Work
#
# Build your notebook below, one concrete step at a time. For each step:
#
# 1. Add a Markdown cell describing what you're about to do and why.
# 2. Add a code cell that does it.
# 3. Run it, check the output, and add `#` comments for anything worth remembering about that line.
#
# Repeat for as many steps as the chapter/unit walks through — including if it introduces a new dataset, a new function, or a new example partway through. Don't feel like you need to force everything into a single sequence if the material doesn't.

# %% [markdown]
# ### Step 2: Calling a Function
#
# Going to create a function alled "split_into_words"

# %%
def split_into_words(any_chunk_of_text):
    lowercase_text = any_chunk_of_text.lower()
    split_words = re.split("\W+", lowercase_text)
    return split_words

# %% [markdown]
# This is now a markdown section
#
# # That is super awesome

# %% [markdown]
# # Step 3 - Creating Variables

# %%
number_of_desired_words = 40

# %%
print(number_of_desired_words)
# Out:
# 40

# %% [markdown]
# ## Creating a filepath and reading in the text

# %%
filepath_of_text = "../texts/literature/The-Yellow-Wallpaper_Charlotte-Perkins-Gilman.txt"

# %%
full_text = open(filepath_of_text, encoding="utf=8").read()

# %%
print(f"Loaded {len(full_text)} characters. Preview: {full_text[:100]}")
# Out:
# Loaded 31497 characters. Preview: THE YELLOW WALLPAPER
#
# By Charlotte Perkins Gilman
#
#
#
# It is very seldom that mere ordinary people lik

# %%
type(full_text)
# Out:
# str

# %%
print(full_text[:200])
# Out:
# THE YELLOW WALLPAPER
#
# By Charlotte Perkins Gilman
#
#
#
# It is very seldom that mere ordinary people like John and myself secure
# ancestral halls for the summer.
#
# A colonial mansion, a hereditary estate, I

# %% [markdown]
# ### Creating a Stop World List

# %%
stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 've', 'll', 'amp']

# %%
type(stopwords)
# Out:
# list

# %% [markdown]
# ## Step 4 - Analysis

# %%
all_the_words = split_into_words(full_text)
meaningful_words = [word for word in all_the_words if word not in stopwords]
meaningful_words_tally = Counter(meaningful_words)
most_frequent_meaningful_words = meaningful_words_tally.most_common(number_of_desired_words)

# %% [markdown]
# ## Output

# %%
most_frequent_meaningful_words
# Out:
# [('john', 45),
#  ('one', 33),
#  ('said', 30),
#  ('would', 27),
#  ('get', 24),
#  ('see', 24),
#  ('room', 24),
#  ('pattern', 24),
#  ('paper', 23),
#  ('like', 21),
#  ('little', 20),
#  ('much', 16),
#  ('good', 16),
#  ('think', 16),
#  ('well', 15),
#  ('know', 15),
#  ('go', 15),
#  ('really', 14),
#  ('thing', 14),
#  ('wallpaper', 13),
#  ('night', 13),
#  ('long', 12),
#  ('course', 12),
#  ('things', 12),
#  ('take', 12),
#  ('always', 12),
#  ('could', 12),
#  ('jennie', 12),
#  ('great', 11),
#  ('says', 11),
#  ('feel', 11),
#  ('even', 11),
#  ('used', 11),
#  ('dear', 11),
#  ('time', 11),
#  ('enough', 11),
#  ('away', 11),
#  ('want', 11),
#  ('never', 10),
#  ('must', 10)]

# %% [markdown]
# ---
#
# ## Failure Log
#
# When I copied the open command, I forget the closing "()" and it broke the code.
#
# -
# -
# -
